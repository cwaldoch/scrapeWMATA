# %%
import pandas as pd
import os, sys, pdb

gas_data = pd.read_csv(r'gas_data.csv')

# %%
"""
Combine FERC 552 dat with daily trading data from ice, price data from platts, and flow data from SNL
seeing less volume done in certain locations, infra biuld out and volume depth, areas without infra volumes is dropping
in the contet of other energy markets there is more data and volume, perhaps less than before with higher prices + low volatility
shell producers tend to sell at index rather than fixed price
traders have left the market which leads to less fixed price trading
commision might help, why people don't report, is the safe harbor provision isn't quite safe enough, a fat finger error could
results in an investigation, participants wants greater safety from issues
system not broken, sysstem weakened by things like banks drawing ou, still robust enough to rpduce good price indices, could
produce better indices
safe harbor was written in 2003 in a very stressful period, references an older time where calls were happening to report, not
so now, emails not phone calls
FERC needs to be clear that partiicpants should report to all indices and such that meet their standards
platts has been seeing an improvement in volumes recently, from a liquidity standpoint, volume is still sufficient, pick up in
index, number of fixed price trades is still sufficient
the total number of humans involved in trading have dropped, have seen counterparties , 280 ICE trading counterparties in
generally, next day trading up ~10% compared to last year, bid week has seen a reduction of ~8%, nobody reports ICE trades,
they happen on the platfor, so they just get them
NGI has see an asymptotic decline in the amount of data, particularly in the daily market, observed volatility and production
was down in 2016, this guy is pretty wrong about gas shocks and natural gas prices, with LNG as the US being subject to price
shocks hat doesn't really make sense, US has a baseline gas price and demand that laregly leaves it as a price setter on the
global market, not a price taker

tetco m3, 53,500mmbtu/day was the amount used, from a price reporter standpoint it's becoming riskier, reporters becoming a
larger portion of the reported prices, leading to them being uncertain, the largest volume increase in the past year, 
9/10 did not report, most of them are marketers


feels like marketis healthy, but that the reporting and availability of data is more limiteed

in the last several years a shift in volumes, new infrastructure in the northeast has pulled away some of the volume,
ICE typically has ~280 parties interacting, first time the ICE guy has seen a 552 breakout in the way that FERC presented it, so
it's probably not so open, total ICE data represents 35% of volume, traders expect ~90% to be on ICE, the financial volummes
continue to grow and expand, the amount of trading and hedging will continue to grow around those pipes

it is a case of how to capture more liquidity

a lot of big utilities and LDCs that use index in that area, so those who were trading fixed price have shifted to index

for june 195000 mmbtus, ice reported for tetcom3, ngi always tells people to index to a regional average, but customers want a
more specific price index, NGI did an analysis of change in production from 2013--2016, only 1/6 of companies that do PRA, the
rest of the positive change is coing from independent producers that are not reporting to PRAs, these independents have
historically not set up trading shops or traded index, but there's a shift going on as they get/become more involved

royalties are based on index prices, which are much lower than the other way in which people are getting paid

utilization of CFTC gidelines on how energy commodity people and others should behave 

as BP unknowingly becomes a larger proportion of the index, it creates/invites risk by essentially forcing them to show their
hand to a greater degree

ICE certianly feels differently than anyone else, once platts and ice data gets fully integrated, a dramatic increase in reported
volume and number of deals should occur, ICE has such a different opinion than the other people
ship channel has some of the largest open interest, but rapidly declining f interest in physical trades at that location

is it a problem of trading or reporting, depends on a market by market basis, utilities' "PECs"?
perhaps this is the time where FERC asks those who are not reporting"why are you not reporting?"

Platts is also seeing a concentrationof indces, the top 5 players for example in 2016, their % of total tradable marke not
changed much about a quarter, but sheo top5 report 43% of reported, and 70% of monthly market, does increase the risk for price
reporting because of the perception that accompanies that

ICE data that platts is incorporating into their survey, that data is exclusive, it's not made avaiable to all price publishers, 


ICE now going into transparency in index formation, doesn't believe it's in anybody's best interest for a totally
transparent market

the in-day trades tend to happen early in the day, and then very difficult to enter into additioanl transactions later in the day
additional premiums they pay for optionality around excess gas are much lower than penalties/costs would pay otherwise

verifiability is probably the most difficult piece of the reporting information requirements to hit

if you are pulishing an index with a low numbe of volumes or deal, put the inf out there regardless, if the market wants to look 
at it, let the market decide for itself

a reduction or deletion of indices with a fewer number of trades will ony increase 
"""

# %%
"""
PANEL 2

trade association for ~1000 small gas systems across the country, these sytems rely a lot on the index, do people have confidence
that these indices accurately reflect the local cost of natural gas

sabine pass 2-2.5bcf/day, 4th train will hit it up to ~3bcf/day, does a lot on a phyiscal basis, but does buy a bunch from 
various counterparties and indices, believe they will publish prices by the end of the year

exxonmobil representing ngsa, very large orgnization, touch on basically everything in the end, generally people are very keen 
to have a robust market with many players and such, like the ability to characterize the pieces of the market, USA has an 
excellent everything already

aga is the LDCs

kinder morgan ~70k miles of pipeline, interestin many plays, a lot of interactions, the indcdes are embedded in 
basically all of hte kinder morgan efforts, 144 mentions in interstate tariffs really wants ICE prices to remain available, 
developing prices is very different than allowing access to raw data

california

transcanada dude has confidence due to a lack of ethane on the natural gas pipelines

macquarie 

kinder mgran had switched to ice, very concerned about their future merging or whatever it is with platts, ice is easy,
transparent anonymous, better price formation, etc. has a bunch of not fully loaded pipes, out in the rockies for example

can be a significant par tof the index now as one person/company/trader, for many years there have been asked of the
commision to better defie what manipulation is, this is maye an opportunity to change that a little bit, to expand the safe
harbor, an expansion that's not just broader languge, but which addresses behavior of traders during bid week

larger participants end up making momre and more of the data, shouldn't mandate it, but at some threshold you need to encourage
the trading of datas, ice does daily bid week reports, which is very helpful, people don't want to report data for fear of 
greater liability or that it will open them up to more liability

aga, non reporting members were so due to costs and regulatory risk, some nonreporting members were considering going back and
startig to report if the safe harbor is opened up

all of thise legislation is ranked fairly evenly, either you can or can't make it work with basel3, which is really just cost 
of capital, if you're subject to stringent capital requirements, regulatory risk is one of the highest, due to high uncertainty
and also the large reputational risk, 

tico went to work with platts to get te tico non ipp put in place, the price change wasn't a reflection of a lack of liquidity,
but it was a recongition of a lack of avialability of data there

when working with people on value of storage, the bid-ask spread comes right off hte value of it first, right away, many 
customers want th be able to hedge off their risk, instead of 3 year contracts in hte past, starting to see shorter contracts
now and reduced rates if it is a longer contract

kinder morgan talking strongly about using idle pipes as a form of storage, specifically "horizontal" storage, out ewst I guess
there's space

cheniere doesn't really change or doubt anything they do in terms of hedging activities based on the indices,
their liquidity or otherwise
"""
# Out:
# "\nCombine FERC 552 dat with daily trading data from ice, price data from platts, and flow data from SNL\nseeing less volume done in certain locations, infra biuld out and volume depth, areas without infra volumes is dropping\nin the contet of other energy markets there is more data and volume, perhaps less than before with higher prices + low volatility\nshell producers tend to sell at index rather than fixed price\ntraders have left the market which leads to less fixed price trading\ncommision might help, why people don't report, is the safe harbor provision isn't quite safe enough, a far finger error could\nresults in an investigation, participants wants greater safety from issues\nsystem not broken, sysstem weakened by things like banks drawing ou, still robust enough to rpduce good price indices, could\nproduce better indices\nsafe harbor was written in 2003 in a very stressful period, references an older time where calls were happening to report, not\nso now, emails not phone c
# ...

# %%
"""
PANEL 3
cheniere wants voluntary reporting
joe: very surprised in support of indices, no empirical evidence that these indices represent usable or real gas costs,
doing an evidence based investigation of gas costs, look at low and high demeand days to see if they have a statistically
reasonable smple to show that it's not biased, I have no reason to believe it's not biased-
I mean no reason to view it either way"

perceived regulatory risk needs to be addressed, updating the safe harbor, hit on again, audits not that burdensome,
reporting is very useful, everyone should do it, should make it clear that burden isn't harder on reporting entities

8 are marketing companies of the 9 of the 10 biggest in 2016 that do not report
also, marketing affiliates of pipelines that do not report

index price gas has increased basically every year for the past 9 years
dramatic shift from fixed priced gas that report to indexed gas in terms of reports which show =s those companies putting their
money behind these indices

rice professor, my budget can't support that type of thing because it's so expensive to buy, NGI guy went up and gave him a card

kinder morgan handles ~40% of the gas in the US on the daily basis, kinder morgan chief legal officer pushing bakc against FERC
audits and investigation, wants more training for auditors, clearer focus of the audit, audits take 2-3 years in some cases,
the agency doens't provide routinely in any timeline when the audit is closed, because a price reporter, routinely provided
with subpoenas, just to handle the basic data questions, and that is a percetion of being a price reporter, price reporters
being subject to subpoenas out of of other audits or investigations, very confident in the dat, work with platts, ice, and argus,
all had previous perspectives to data, platts applying some editorial perspective, ngi not doing that, need the history, use the
history regularly to do their own assessment, need forward market, need to look at real and now trades, worried about access of
data and the concentration of data behind paywalls need more transparency and access to data and competition to reduce data price

ICE again, support for clarity on safe harbor, clarity on report just daily or weekly or both, stats bear out in a pretty
decent bottom in the amount of trades executed on daily transactions 

clear differneces between prices from different PRAs, at ties there really are, from cheniere's perspective they will report to
multipe PRAs, however, doesn't feel it's the function of the PRAs to go and provide a price where there currently isn't one, then
you get into a whole differnet set of issues, believe that if submitted data then should have some other access or cost changes

joe not enough data do not pretend three's a price there, not sure why the overwhelming confidence in indices, except hwen bad
days do not used indices, pjm does not use indices at all, only uses ice, indices are not timely, they basically don't matter, 
should only use real data, indices are worthless

platts, biggest request they get by far is to provide that transparency and assess a price where there is not data so that there
is a value, various reasons for this, maybe a bilateral or something, natural gas doens't have named parties and ocunter parties
unlike oil market, essentially decided by participants, counterparty index of concentration over time

tenaska, coming in against joe, they're not blindly comfortable wiht the indices, it's a combinaiton of data avialable and
other pieces, plus their ability to think about things and tie stuff to other indices as it becomes important, so be flexible
think a significant regulatory intervention is not required at this point

joe - why is it you believe, why would you think it is representative of hte mean value of the trades, if it's just one trader
only 10% of the trades, not calling for a regulatory intervention, just want to have a more scientific approach

energy intelligence, should have a more robust price reporting, but it's not that complicated, they're volume-weighted averages,
love the idea of price leveling, we could make some money, haha sorry, just want to kep it in perspective, to make that point
whomever gets it we volume-weight it

BP Energy, coming at it fomr both market liquidity index, but also, the major 3-5 companies, BP included, it's the risk that
we're taking on, can't just get ther eby being encouraging, need to do something, more than just encouragement, some happy medium
where for example if you're a marketer, if you're buying and selling should be in your best interest in terms of efficiency of
knowledge and its availability, mandatory reporting for marketers, amending the certificates for marketers, if you did that just
from the top 10, a very robust and large number would be coming out

curt, kinder morgan, in the 80s, 90s, the agency started to get out of the market and it got a lot better, when expressing
concern about the platts ice transaction what are the exclusivities, that's the problem, not price, want availabiity for
others so that there can be price competition in the index world

ICE, in general going to have a lot omre counterparties, ICE has averages 300 counterparites the last 7 years, PRAs getting 30-40
ICE lost the price setting war, data used to be available to customers from 2001 and on, really hate the idea of anything
mandatory, him and cheniere going at it, a bit about levelized prices 

hor price reporters could be affected or 552 instructions, now nonreporters prices going into the platts index,
how does this work and apply?

S&P Platts, thought long and hard about 3rd part data and involuntary use and identification of 3rd party data, woulnd't want
to creat e amethodology or processes that bring some increased perceived risk

platts still gathering feedback on how ot handle an ice trade or non ice trade, so whether it should be weighted or what, 

energy intelligence going kind of hard at platts over their possible process for integrating ICE trade data

platts, yes the verifiability of the ice data is different than the other data because it is anonymous, but the manner by which
that transaction occurred was diffferent and much more transparent, platts thinks it's just as good as reported prices, use
the same methodology for scrutinization

ICE pushing back against all of that now, sticking up for transaction/market data 

Joe, surprised platts is going to start weighting and picking and choosing which data to use, wants to respond not so kindly to
ice earlier, pjm market has all the data in it, prices were formed by the transactions, so much more data than an index, it's
not even close, what makes up transparency, etc. 

joe fliside of everything you hear about liquidit yproblems is that market power can develop, but wthere is another side to
it in which these things evolve, and markets are not self-correcting

the turn of the centruy price issues are frightening, so this perceived fear of regulatory action, why take the risk at all, 
although bakc then there was a very different form of price discovery, more safe harbor talk

"""

# %%
# END GOAL: assign specific flows to LDCs and individual connections, but what should it look like?
# incorporate ibrt changes and developed a possible, actual, iso, bid, and etc fuel price for eah generator based on
# an expectation of embodied costs that varies with the day's bids and prices

find typical 90% operating range
remove outliers
calculate heat rate from epa data

# %%
plant_meter_pipe_dict = {}

for plants in plants:
    plant_meter_pipe_dict[plant] = [meter, pipeline]
    
# now you have a dictionary of plants and locatio

get_pipeline_order(pipeline):
    
    meter_order = {}
    
    for meter in meters:
        meter_order[meter] = [pipeline, order]

# %%
import matplotlib.pyplot as plt
import random
flows_out = []
flows_in = []


for i in range(0,5000):
    flows_out.append(random.randint(1,300))
    flows_in.append(random.randint(1,300))

# %%
print(len(flows_in))
# Out:
# 5000

# %%
import numpy as np
print(np.sum(flows_in))
print(np.sum(flows_out))
# Out:
# 751939
# 755593

# %%
flows_out = [x*-1 for x in flows_out]

# %%
print(np.sum(flows_out))
# Out:
# -755593

# %%
#plt.style.use('ggplot')
#plt.style(background = 'white')
# secon dary axis showing cumulative deliveries and receipts

plt.bar(range(0,len(flows_in)),flows_in, edgecolor = '#F5F5F5')#, width = 0.01, edgecolor='blue')
plt.bar(range(0,len(flows_out)),flows_out, edgecolor = '#F4F4F4')#, width = 0.01,edgecolor='green')
plt.ylim(-400,400)
plt.show()
#plt.savefig(r'C:\Users\cwaldoch\test_flows.png', dpi=300)
#plt.close()

# %%
plt.close()

# %%
import matplotlib
help()
# Out:
# Welcome to Python 3.5's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at http://docs.python.org/3.5/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> matplotlib
# Help on package matplotlib:
#
# NAME
#     matplotlib - This is an object-oriented plotting library.
#
# DESCRIPTION
#     A procedural interface is provided by the companion pyplot module,
#     which may be imported directly, e.g.::
#
#         import matplotlib.pyplot as plt
#
# ...

# %%
from matplotlib import rcParams
print(rcParams)
